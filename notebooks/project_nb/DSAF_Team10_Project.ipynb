# %% [markdown]
# ## **Predicting Bank Failures Using Machine Learning**
#
# ***Project Overview***
#
# The United States Federal Deposit Insurance Corporation (FDIC) maintains user faith in the banking system by insuring deposits at select financial institutions up to $250,000. This is generally complemented by an in depth monitoring and risk assessment, to hold financial institutions accountable to just banking standards, and manage turbulent times, all with the end goal of limiting the economic impact of a bank failure.
#
# To assist with risk mitigation, the FDIC assigns a "Bank Score" to all insured institutions, which is a measure of "forward-looking risk measures" as well as historical performance (*FDIC Risk Based Assessments*, FDIC.gov). This is already a highly complex statistical model that relies heavily on reviewer discretion and a rigid scorecard, rather than specific bank data or indicators. This creates an opportunity to explore the potential of applying a machine learning model to FDIC collected data to ultimately predict bank health and supplement professional skepticism when analyzing these financial institutions.
#
# **Can the FDIC implement Machine Learning models to perform additional anaylsis of large financial institutions for riskiness?** The FDIC's 2023 budget alone is $2.409 billion, specifically indended to "modernize and enhance the FDIC's information technology infrastructure" (*FDIC Board Approves 2023 Operating Budget*, FDIC.gov). Embodying AI to assist with regulatory practices could save time and improve accuracy for an institution crucial to American Financial Instutions, while reducing costs in the long run. This model categorizes large financial institutions (small banks have a separate scoring system) as risky or safe, based on publicly available banking data. FDIC scores large financal institutions risk between 0 and 100, though for purposes of banking and the importance of using healthy institutions, we define the risky/safe cutoff as **75** as opposed to 50. We use publicly available data provided by the FDIC via the Homeland Infrastructure Foundation. We acknowledge that this data is from 2016, meaning it does not contain banking data or newer institutions. However, the model and fields are still collected and reported by the FDIC, and once obtaining current data, one could apply this model to draw meaningful conclusions going forward.

# %% [markdown]
# ***Model Development and Operational Details***
#
# In this workbook, we perform in depth exploratory data analysis, data wrangling, and finally apply a logistic regression analysis to categorize banks as risky or healthy, in line with the FDIC's collected data. As discussed above, we use the Homeland Infrastructure Foundation's 2016 FDIC Insured Banks Data Set.

# %% [markdown]
# # Imports

# %%
##Install Packages
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 10)
import numpy as np
import sklearn.tree
import sklearn.metrics
import sklearn.model_selection
import graphviz
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from IPython.display import Image

# %% [markdown]
# # Loading data

# %% [markdown]
# ## Geographical data

# %%
##Loading Data
dfg = pd.read_csv('https://drive.google.com/uc?export=download&id=1vD7uj5Tpz2IvDj49YXR_4Xw2Pebhk_Ix')
dfg
# Out:
# /var/folders/0q/3y5dk4390kqc86qh28v817lw0000gn/T/ipykernel_7520/2117010362.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfg = pd.read_csv('https://drive.google.com/uc?export=download&id=1vD7uj5Tpz2IvDj49YXR_4Xw2Pebhk_Ix')
#        index    FID                              ADDRESBR  BRNUM  BRSERTYP  \
# 0          0  13001                       950 Park Street      0        11
# 1          1  13002                        97 Lowell Road    360        11
# 2          2  13003                       342 Main Street      0        11
# 3          3  13004                       121 Main Street      0        11
# 4          4  13005                           205 Main St      0        11
# ...      ...    ...                                   ...    ...       ...
# 94720  94720  93996             9176 Conroy Windermere Rd   7864        11
# 94721  94721  93997             10975 Tamiami Trail North   7865        11
# 94722  94722  93998  855 El Camino Real, Bldg 2, Suite 67   7866        11
# 94723  94723  93999                 13824 Narcoossee Road   7867        11
# 94724  94724  94000                2025 Indian River Blvd   7868        11
#
#        CBSABR                            CBSANAMB         CITYBR  \
# 0       14460      Boston-Cambridge-Newton, MA-NH      Stoughton
# 1       14460      Boston-Cambridge-Newton, MA-NH        Concord
# 2       14460      Boston-Cambridge-Newton, MA-NH      Wakefield
# 3       12700                 Barnstable Town, MA  Yarmouth Port
# 4           0                                              Frost
# ...       ...                                 ...            ...
# 94720   36740       Orlando-Kissimmee-Sanford, FL     Windermere
# 94721   34940   Naples-Immokalee-Marco Island, FL         Naples
# 94722   41940  San Jose-Sunnyvale-Santa Clara, CA      Palo Alto
# 94723   36740       Orlando-Kissimmee-Sanford, FL        Orlando
# 94724   42680            Sebastian-Vero Beach, FL     Vero Beach
#
#             CNTRYNAB      CNTYNAMB  DEPSUMBR GEOCODE_CE GEOCODE__1  \
# 0      United States       Norfolk     46645       2007     456101
# 1      United States     Middlesex    154554       1039     361300
# 2      United States     Middlesex     74480       4016     335100
# 3      United States    Barnstable    144528       2017      11802
# 4      United States     Faribault     34860       1197     460500
# ...              ...           ...       ...        ...        ...
# 94720  United States        Orange     85637       2046      14809
# 94721  United States       Collier      4446       3003      10110
# 94722  United States     San Mateo      2239       1052     511609
# 94723  United States        Orange      8050       1167      16704
# 94724  United States  Indian River      3181       2000      50401
#
#                                   NAMEBR STALPBR  STCNTYBR       STNAMEBR  \
# 0            Stoughton Co-Operative Bank      MA     25021  Massachusetts
# 1                         Concord Branch      MA     25017  Massachusetts
# 2            Wakefield Co-Operative Bank      MA     25017  Massachusetts
# 3             Cape Cod Co-Operative Bank      MA     25001  Massachusetts
# 4                       Frost State Bank      MN     27043      Minnesota
# ...                                  ...     ...       ...            ...
# 94720                   Isleworth Branch      FL     12095        Florida
# 94721         US 41 and Immokalee Branch      FL     12021        Florida
# 94722  Town and Country Palo Alto Branch      CA      6081     California
# 94723       Narcoossee & Laureate Branch      FL     12095        Florida
# 94724                Miracle Mile Branch      FL     12061        Florida
#
#        UNINUMBR  ZIPBR   CERT               ADDRESS       ASSET BKCLASS  \
# 0         33215   2072  26513       950 Park Street       96326      SM
# 1         33217   1742  57957    One Citizens Plaza   100642478       N
# 2         33218   1880  26516       342 Main Street      174742      SB
# 3         33219   2675  26517       121 Main Street      745395      SB
# 4         33221  56033  26519           205 Main St       39881      NM
# ...         ...    ...    ...                   ...         ...     ...
# 94720    552034  34786    628  1111 Polaris Parkway  2002047000       N
# 94721    552035  34108    628  1111 Polaris Parkway  2002047000       N
# 94722    552036  94301    628  1111 Polaris Parkway  2002047000       N
# 94723    552037  32832    628  1111 Polaris Parkway  2002047000       N
# 94724    552038  32960    628  1111 Polaris Parkway  2002047000       N
#
#                 CITY        CNTRYNA  DENOVO      DEPDOM  \
# 0          Stoughton  United States       0       75160
# 1         Providence  United States       0    68755303
# 2          Wakefield  United States       0      147124
# 3      Yarmouth Port  United States       0      554956
# 4              Frost  United States       0       34860
# ...              ...            ...     ...         ...
# 94720       Columbus  United States       0  1032549000
# 94721       Columbus  United States       0  1032549000
# 94722       Columbus  United States       0  1032549000
# 94723       Columbus  United States       0  1032549000
# 94724       Columbus  United States       0  1032549000
#
#                                         NAMEFULL  \
# 0                    Stoughton Co-operative Bank
# 1            Citizens Bank, National Association
# 2                    Wakefield Co-operative Bank
# 3                     Cape Cod Co-operative Bank
# 4                               Frost State Bank
# ...                                          ...
# 94720  JPMorgan Chase Bank, National Association
# 94721  JPMorgan Chase Bank, National Association
# 94722  JPMorgan Chase Bank, National Association
# 94723  JPMorgan Chase Bank, National Association
# 94724  JPMorgan Chase Bank, National Association
#
#                                 NAMEHCR REGAGNT                    REPDTE  \
# 0                                           FED  2014-06-30T00:00:00.000Z
# 1      UK FINANCIAL INVESTMENTS LIMITED     OCC  2014-06-30T00:00:00.000Z
# 2                                          FDIC  2014-06-30T00:00:00.000Z
# 3               COASTAL AFFILIATES, MHC    FDIC  2014-06-30T00:00:00.000Z
# 4                                          FDIC  2014-06-30T00:00:00.000Z
# ...                                 ...     ...                       ...
# 94720              JPMORGAN CHASE & CO.     OCC  2014-06-30T00:00:00.000Z
# 94721              JPMORGAN CHASE & CO.     OCC  2014-06-30T00:00:00.000Z
# 94722              JPMORGAN CHASE & CO.     OCC  2014-06-30T00:00:00.000Z
# 94723              JPMORGAN CHASE & CO.     OCC  2014-06-30T00:00:00.000Z
# 94724              JPMORGAN CHASE & CO.     OCC  2014-06-30T00:00:00.000Z
#
#         RSSDID STALP  STCNTY         STNAME    ZIP  BKMO       LOC_NAME  \
# 0       164975    MA   25021  MASSACHUSETTS   2072     1   PointAddress
# 1      3303298    RI   44007   RHODE ISLAND   2903     0   PointAddress
# 2       330873    MA   25017  MASSACHUSETTS   1880     1   PointAddress
# 3       119779    MA   25001  MASSACHUSETTS   2675     1  StreetAddress
# 4       943853    MN   27043      MINNESOTA  56033     1  StreetAddress
# ...        ...   ...     ...            ...    ...   ...            ...
# 94720   852218    OH   39041           OHIO  43240     0  StreetAddress
# 94721   852218    OH   39041           OHIO  43240     0   PointAddress
# 94722   852218    OH   39041           OHIO  43240     0   PointAddress
# 94723   852218    OH   39041           OHIO  43240     0  StreetAddress
# 94724   852218    OH   39041           OHIO  43240     0  StreetAddress
#
#       STATUS  SCORE           x          y               GeocodeSou
# 0          M    100  -71.073321  42.111569  HSIP USA_ZIP4 Composite
# 1          M    100  -71.352231  42.463779  HSIP USA_ZIP4 Composite
# 2          M    100  -71.071241  42.504579  HSIP USA_ZIP4 Composite
# 3          M    100  -70.252098  41.703698  HSIP USA_ZIP4 Composite
# 4          M    100  -93.923821  43.584759  HSIP USA_ZIP4 Composite
# ...      ...    ...         ...        ...                      ...
# 94720      M    100  -81.511215  28.493529  HSIP USA_ZIP4 Composite
# 94721      M    100  -81.801661  26.271220  HSIP USA_ZIP4 Composite
# 94722      M    100 -122.160481  37.437761  HSIP USA_ZIP4 Composite
# 94723      M    100  -81.244670  28.365735  HSIP USA_ZIP4 Composite
# 94724      M    100  -80.380410  27.638795  HSIP USA_ZIP4 Composite
#
# [94725 rows x 43 columns]

# %% [markdown]
# https://drive.google.com/file/d/1vD7uj5Tpz2IvDj49YXR_4Xw2Pebhk_Ix/view?usp=share_link

# %% [markdown]
# Andrew: REVIEW DATA FIELDS, WALK THROUGH CLEANING, WALK THROUGH MODEL BUILD, ACKNOWLEDGE BIASES (Geographical, etc.)
#
# Divya:
# - Early columns are geography; should be less important. We can use state and/or zip code to simplify; no point in going address-level imo. Regarding Andrew's comment, we can do an early check to see how well different geos are represented in the data, but that'll probably be linked to general population and financial metrics in those zip codes.
# - Downloaded the CSV... Where is all the financial data?? I only see geo data...
# - Source of labels of Bank Failure: https://banks.data.fdic.gov/bankfind-suite/failures
#     - goes from 2012 to 2020
#     -

# %% [markdown]
# ## Financial data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Bank Failure Data, possible source of labels. Maybe can join on some financial ID
dff = pd.read_csv('/content/drive/MyDrive/BankFailures.csv', error_bad_lines=False)
dff

# %% [markdown]
# # Data exploration

# %%
mr1 = dfg['NAMEBR'].str.contains('Wakefield')
mr2 = dfg['FID'] == 3983
dfg.loc[mr2, :]

mr1 = dff['FIN'] == 93996
dff.loc[mr1, :]

# %% [markdown]
# ## Understanding how to merge geographical and financial data

# %%
## Simplifying datasets to simplify assesment

### Geographical dataset
g_rc = [
    'FID',
    'CERT',
    'STALPBR',
    'CITY',
    'CITYBR',
    'CNTYNAMB',
    'NAMEFULL',
    'NAMEBR',
    # 'SCORE',
]
dfg1 = dfg.loc[:, g_rc].copy()

### Financial dataset
f_rc = [
    'CERT',
    'ID',
    'FIN',
    'STATE',
    'CITY',
    'NAME_DOUBLEQUOTES',
]
dff1 = dff.loc[:, f_rc].copy()


## Merging datasets and evaluating results
dfx = pd.merge(
    left=dfg1,
    right=dff1,
    how='left',
    left_on='FID',
    right_on='ID',
    suffixes=('_dfg', '_dff'),
)

mr1 = dfx['CERT_dff'].notnull()
dfx.loc[mr1, :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/educacion/maestria/berkeley_mba_meng/academics/2023_spring/data_science_applied_to_finance_and_accounting/UCB_gclass_ds_for_finance_and_accounting/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CERT_y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [36], in <cell line: 39>()
#      29 ## Merging datasets and evaluating results
#      30 dfx = pd.merge(
#      31     left=dfg1,
#      32     right=dff1,
#    (...)
#      36     suffixes=('_dfg', '_dff'),
#      37 )
# ---> 39 mr1 = dfx['CERT_y'].notnull()
#      40 dfx.loc[mr1, :]
#
# File ~/Documents/educacion/maestria/berkeley_mba_meng/academics/2023_spring/data_science_applied_to_finance_and_accounting/UCB_gclass_ds_for_finance_and_accounting/.venv/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Documents/educacion/maestria/berkeley_mba_meng/academics/2023_spring/data_science_applied_to_finance_and_accounting/UCB_gclass_ds_for_finance_and_accounting/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'CERT_y'

# %% [markdown]
# # Data wrangling

# %% [markdown]
# # Feature engineering

# %% [markdown]
# # Building model

# %% [markdown]
# # Evaluating model

# %% [markdown]
# # *Additional notes*

# %% [markdown]
# ##### Code adjustments to run locally

# %%
## Code line to read bank failure data locally
dff = pd.read_csv('BankFailuresCleaned - BankFailures.csv')
